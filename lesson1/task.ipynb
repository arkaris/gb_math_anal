# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def my_cos(X, k=1):
    return np.cos(k*X)

x = np.linspace(0, 7, 100)
y1 = my_cos(x)
y2 = my_cos(x, 2)

# %%
plt.plot(x, y1)
plt.plot(x, y2)
